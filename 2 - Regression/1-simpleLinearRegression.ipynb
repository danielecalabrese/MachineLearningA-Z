# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing dataset

# %%
dataset = pd.read_csv('Salary_Data.csv') # il csv ha due colonne: Anni di esperienza e Stipendio
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
X = dataset.iloc[:, 0].values
y = dataset.iloc[:, 1].values

# %%
print(X)
# Out:
# [ 1.1  1.3  1.5  2.   2.2  2.9  3.   3.2  3.2  3.7  3.9  4.   4.   4.1
#   4.5  4.9  5.1  5.3  5.9  6.   6.8  7.1  7.9  8.2  8.7  9.   9.5  9.6
#  10.3 10.5]

# %%
print(y)
# Out:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %% [markdown]
# ## Splitting dataset into Test set and Train set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# %%
X_train = X_train.reshape(-1, 1) # il modello di regressione lineare di sklearn si aspetta un array 2D, quindi dobbiamo trasformare X_train in una matrice con una sola colonna. Puoi controllare le dimensioni con print(X_train.shape). Questa funziona non modifica X_train, ma restituisce una nuova matrice con le dimensioni corrette.
X_test = X_test.reshape(-1, 1) # lo stesso per X_test
print(X_train)
# Out:
# [[ 2.9]
#  [ 5.1]
#  [ 3.2]
#  [ 4.5]
#  [ 8.2]
#  [ 6.8]
#  [ 1.3]
#  [10.5]
#  [ 3. ]
#  [ 2.2]
#  [ 5.9]
#  [ 6. ]
#  [ 3.7]
#  [ 3.2]
#  [ 9. ]
#  [ 2. ]
#  [ 1.1]
#  [ 7.1]
#  [ 4.9]
#  [ 4. ]]

# %% [markdown]
# ## Training the Simple Regression model on train set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# ## Visualize the Training set results

# %%
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.title('Stipendio vs Anni di esperienza (Training set)')
plt.xlabel('Anni di esperienza')
plt.ylabel('Stipendio')
plt.show()

# %% [markdown]
# ## Visualize the Test set result

# %%
plt.scatter(X_test, y_test, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.title('Stipendio vs Anni di esperienza (Test set)')
plt.xlabel('Anni di esperienza')
plt.ylabel('Stipendio')
plt.show()

# %% [markdown]
# ## Bonus: Making a single prediction (for example the salary of an employee with 12

# %%
print(regressor.predict([[12]])) # vuole sempre un array 2D
# Out:
# [138967.5015615]

# %% [markdown]
# ## Bonus: Getting the final linear regression equation with the values of the coefficient

# %%
print(regressor.coef_) # parametro b_1
print(regressor.intercept_) # parametro b_0
# Out:
# [9345.94244312]
# 26816.19224403119
